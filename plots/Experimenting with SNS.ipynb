# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('csvForGraphs.csv')

# %%
sns.countplot(x="officer_gender", data=df, palette='GnBu_d', saturation=.5)

# %%
sns.countplot(x="officer_race", data=df, palette='GnBu_d', saturation=.5)
